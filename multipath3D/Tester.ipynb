# %%
import torch
import SimpleITK as sitk
import numpy as np
from scipy.ndimage.measurements import label
from skimage.morphology import erosion, dilation
import nibabel as nib
from torch.autograd import Variable
from skimage.transform import resize
from tqdm import tqdm_notebook as tqdm
import os
from model import BrainNet_3D, BrainNet_3D_Inception
from scipy.ndimage import uniform_filter, maximum_filter
net = BrainNet_3D_Inception()
# net = BrainNet_3D()

# %%
os.environ["CUDA_VISIBLE_DEVICES"]="0"
# ckpt = torch.load('/media/brats/Kori/Kaminstas_2018/models/model-m-15062018-233418-BrainNet_3D_Inception_loss = 0.7610744878227615_acc = 0.7903060229355852_best_acc.pth.tar')
ckpt = torch.load('/media/brats/MyPassport/Avinash/Kaminstas_2018/models/model-m-20062018-122650-BrainNet_3D_Inception_layer_loss = 0.665126177186065_acc = 0.7872223666348959_best_acc.pth.tar')
net.load_state_dict(ckpt['state_dict'])
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-4-cf1cc6ff3a6d> in <module>()
#       2 # ckpt = torch.load('/media/brats/Kori/Kaminstas_2018/models/model-m-15062018-233418-BrainNet_3D_Inception_loss = 0.7610744878227615_acc = 0.7903060229355852_best_acc.pth.tar')
#       3 ckpt = torch.load('/media/brats/MyPassport/Avinash/Kaminstas_2018/models/model-m-20062018-122650-BrainNet_3D_Inception_layer_loss = 0.665126177186065_acc = 0.7872223666348959_best_acc.pth.tar')
# ----> 4 net.load_state_dict(ckpt['state_dict'])
#
# ~/anaconda3/lib/python3.6/site-packages/torch/nn/modules/module.py in load_state_dict(self, state_dict, strict)
#     719         if len(error_msgs) > 0:
#     720             raise RuntimeError('Error(s) in loading state_dict for {}:\n\t{}'.format(
# --> 721                                self.__class__.__name__, "\n\t".join(error_msgs)))
#     722
# ...

# %%
nclasses = 5
net.eval()
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
def bbox(vol):
    tumor = np.where(vol>0)

    x_min = np.min(tumor[0])
    y_min = np.min(tumor[1])
    z_min = np.min(tumor[2])

    x_max = np.max(tumor[0])
    y_max = np.max(tumor[1])
    z_max = np.max(tumor[2])
    
    return x_min, x_max, y_min, y_max, z_min, z_max        


def perform_postprocessing(vol, thresh = 0.50, verbose=False):
    label_vol, label_masks = label(vol)
    volumes = []
    for i in range(label_masks):
        x, y, z = np.where(label_vol == i+1)
        v = (np.max(x) - np.min(x)) * (np.max(y) - np.min(y)) * (np.max(z) - np.min(z))
        volumes.append(v)
        
    if verbose:	print ("Max. Volume: {}".format(np.max(volumes)) + " Min. Volumes: {}".format(np.min(volumes)))

    for i in range(len(volumes)):
        if volumes[i] < np.max(volumes) * thresh:
            label_vol[label_vol == i+1] = 0

    label_vol[label_vol > 0] = 1
    return label_vol * vol

def normalize(img,mask):
    mean=np.mean(img[mask!=0])
    std=np.std(img[mask!=0])
    return (img-mean)/std

def get_localization(t1, t1ce, t2, flair):
    mask_rcnn_pred = 0
    return mask_rcnn_pred

def inner_class_classification(t1, t1ce, t2, flair, mask, model):
    shape = mask.shape # to exclude batch_size
    final_prediction = np.zeros((shape[0], shape[1], shape[2]))
    x_min, x_max, y_min, y_max, z_min, z_max = bbox(mask)
#     x_min, x_max, y_min, y_max, z_min, z_max = 25, 210, 25, 210, 25, 120
    
    for x in tqdm(range(x_min, x_max, 9)):
        for y in range(y_min, y_max, 9):
            for z in range(z_min, z_max, 9):
                high = np.zeros((1, 4, 25, 25, 25))
                low  = np.zeros((1, 4, 19, 19, 19))

                high[0, 0, :, :, :] = flair[x-8:x+17, y-8:y+17, z-8:z+17]
                high[0, 1, :, :, :] = t2[x-8:x+17, y-8:y+17, z-8:z+17]
                high[0, 2, :, :, :] = t1[x-8:x+17, y-8:y+17, z-8:z+17]
                high[0, 3, :, :, :] = t1ce[x-8:x+17, y-8:y+17, z-8:z+17]

                low[0, 0, :, :, :]  = resize(flair[x-21:x+30, y-21:y+30, z-21:z+30], (19,19,19))
                low[0, 1, :, :, :]  = resize(t2[x-21:x+30, y-21:y+30, z-21:z+30], (19,19,19))
                low[0, 2, :, :, :]  = resize(t1[x-21:x+30, y-21:y+30, z-21:z+30], (19,19,19))
                low[0, 3, :, :, :]  = resize(t1ce[x-21:x+30, y-21:y+30, z-21:z+30], (19,19,19))
                
                high = Variable(torch.from_numpy(high)).to(device).float()
                low  = Variable(torch.from_numpy(low)).to(device).float()
                pred = torch.exp(model(high, low).detach()).cpu().numpy()

                pred = np.argmax(pred, axis=1)
                final_prediction[x:x+9, y:y+9, z:z+9] = pred[0]
                
    return np.uint8(final_prediction)


def get_whole_tumor(data):
    return (data>0)*(data<4)

def get_tumor_core(data):
    return np.logical_or(data==1,data==3)

def get_enhancing_tumor(data):
    return data==3

def get_dice_score(prediction, ground_truth):
    masks=(get_whole_tumor, get_tumor_core, get_enhancing_tumor)
    p    =np.uint8(prediction)
    gt   =np.uint8(ground_truth)
    # print(np.unique(p),np.unique(gt))
    wt,tc,et=[2*np.sum(func(p)*func(gt)) / (np.sum(func(p)) + np.sum(func(gt))+1e-6) for func in masks]
    return wt, tc, et

# %%
net = net.to(device)
LGG_names = ['Brats18_TCIA13_630_1','Brats18_TCIA10_152_1', 'Brats18_TCIA09_620_1', 'Brats18_2013_15_1']
HGG_names = ['Brats18_TCIA03_474_1', 'Brats18_TCIA08_167_1', 'Brats18_2013_10_1', 'Brats18_TCIA02_322_1']
for name in HGG_names:
    root_path = '../MICCAI_BraTS_2018_Data_Training/HGG/'+name+'/'
    path = root_path + name +'_'

    mask  =  np.uint8(nib.load(path+'seg.nii.gz').get_data())
    brain_mask = np.uint8(nib.load(root_path + 'mask.nii.gz').get_data())
    seg   =  np.uint8(nib.load(path+'seg.nii.gz').get_data())
    seg[(brain_mask != 0) * (seg <= 0)] = 5 #Brain tissue

    flair =  normalize(nib.load(path+'flair.nii.gz').get_data(), brain_mask)
    t1    =  normalize(nib.load(path+'t1.nii.gz').get_data(), brain_mask)
    t1ce  =  normalize(nib.load(path+'t1ce.nii.gz').get_data(), brain_mask)
    t2    =  normalize(nib.load(path+'t2.nii.gz').get_data(), brain_mask)
    affine=  nib.load(path+'seg.nii.gz').affine

    seg[seg == 4] = 3
    seg[seg == 5] = 4

    # mask = get_localization(t1, t1ce, t2, flair)
    # mask = perform_postprocessing(mask)
    final_pred     = inner_class_classification(t1, t1ce, t2, flair, mask, net)
    wt, tc, et     = get_dice_score(final_pred, seg)
    print ('score without filter wt_dice_score = '+str(wt)+'; tc_dice_score='+str(tc)+'; et_dice_score='+str(et))
    
    final_pred1 = maximum_filter(final_pred, size = 2, mode='constant', cval=0)
    wt, tc, et  = get_dice_score(final_pred1, seg)
    print ('score without filter wt_dice_score = '+str(wt)+'; tc_dice_score='+str(tc)+'; et_dice_score='+str(et))

#     final_pred[final_pred == 4] = 0
#     final_pred[final_pred == 3] = 4
#     vol = nib.Nifti1Image(final_pred, affine)
#     vol.set_data_dtype(np.uint8)
#     nib.save(vol, './test_'+name+'.nii.gz')
# Out:
# ...
# /home/brats/anaconda3/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# score without filter wt_dice_score = 0.9554681808775488; tc_dice_score=0.9425535605822597; et_dice_score=0.8203941686035522
# score without filter wt_dice_score = 0.9439507860536944; tc_dice_score=0.9398702049693081; et_dice_score=0.8701699407051515
# ...
# score without filter wt_dice_score = 0.9495945507594444; tc_dice_score=0.9370649226893407; et_dice_score=0.9014209429563302
# score without filter wt_dice_score = 0.9454400019812942; tc_dice_score=0.9273658623630591; et_dice_score=0.8684325693834594
# ...
# score without filter wt_dice_score = 0.8643394106939178; tc_dice_score=0.96135403392662; et_dice_score=0.8829963018194509
# ...

# %% [markdown]
# ### =====================

# %%
model = model.to(device)
path = '/home/uavws/pranjal/MICCAI_BraTS_2018_Data_Training/HGG_patches/Brats18_CBICA_ANZ_1/'

patches  = next(os.walk(path))[1]
wts, tcs, ets = [], [], []
count = 0
for patch in tqdm(patches):
    if patch.__contains__('NON'):
        continue
#     print (patch)
    mask  =  nib.load(path+'/'+patch+'/'+'seg_9cube.nii.gz').get_data()
    seg   =  nib.load(path+'/'+patch+'/'+'seg_9cube.nii.gz').get_data()
    flair =  nib.load(path+'/'+patch+'/'+'flair_high_res_25cube.nii.gz').get_data()
    t1    =  nib.load(path+'/'+patch+'/'+'t1_high_res_25cube.nii.gz').get_data()
    t1ce  =  nib.load(path+'/'+patch+'/'+'t1ce_high_res_25cube.nii.gz').get_data()
    t2    =  nib.load(path+'/'+patch+'/'+'t2_high_res_25cube.nii.gz').get_data()
    affine=  nib.load(path+'/'+patch+'/'+'seg_9cube.nii.gz').affine
    seg[seg == 4] = 3
    high = np.zeros((1, 4, 25, 25, 25))
    low  = np.zeros((1, 4, 19, 19, 19))


    high[0, 0, :, :, :] = flair
    high[0, 1, :, :, :] = t2
    high[0, 2, :, :, :] = t1
    high[0, 3, :, :, :] = t1ce

    flair =  nib.load(path+'/'+patch+'/'+'flair_low_res_19cube.nii.gz').get_data()
    t1    =  nib.load(path+'/'+patch+'/'+'t1_low_res_19cube.nii.gz').get_data()
    t1ce  =  nib.load(path+'/'+patch+'/'+'t1ce_low_res_19cube.nii.gz').get_data()
    t2    =  nib.load(path+'/'+patch+'/'+'t2_low_res_19cube.nii.gz').get_data()

    low[0, 0, :, :, :] = flair
    low[0, 1, :, :, :] = t2
    low[0, 2, :, :, :] = t1
    low[0, 3, :, :, :] = t1ce

    high = Variable(torch.from_numpy(high)).to(device).float()
    low  = Variable(torch.from_numpy(low)).to(device).float()
    pred = torch.exp(model(high, low).detach()).cpu().numpy()

    pred = np.argmax(pred, axis=1)[0]

    # mask = get_localization(t1, t1ce, t2, flair)
    # mask = perform_postprocessing(mask)
    # final_pred     = inner_class_classification(t1, t1ce, t2, flair, mask, model)
    wt, tc, et     = get_dice_score(pred, seg)
#     print ('wt_dice_score = '+str(wt)+'; tc_dice_score='+str(tc)+'; et_dice_score='+str(et))
    wts.append(wt)
    tcs.append(tc)
    ets.append(et)
    count += 1
#     vol = nib.Nifti1Image(pred, affine)
#     vol.set_data_dtype(np.uint8)
#     nib.save(vol, './test.nii.gz')
# Out:
#   2%|▏         | 18/1034 [00:09<09:13,  1.84it/s]/home/uavws/anaconda3/lib/python3.6/site-packages/tqdm/_monitor.py:89: TqdmSynchronisationWarning: Set changed size during iteration (see https://github.com/tqdm/tqdm/issues/481)
#   TqdmSynchronisationWarning)
# 100%|██████████| 1034/1034 [07:00<00:00,  2.46it/s]

# %%
print ('wt_dice_score = '+str(sum(wts)/count)+'; tc_dice_score='+str(sum(tcs)/count)+'; et_dice_score='+str(sum(ets)/count))
# Out:
# wt_dice_score = 0.5906159909379164; tc_dice_score=0.11445181192478461; et_dice_score=0.10873934653009037

# %%
len(wts)
# Out:
# 457

# %%
import numpy as np
def demo(img1 ,img2):
     return(np.random.randint(1,4,size=(9,9,9)))
img=np.zeros((240,240,155))-0.1
img_pad=np.zeros((img.shape[0] + 16,img.shape[1] + 16, img.shape[2] + 16))
img_pad[8: img.shape[0]+ 8, 8: img.shape[1]+ 8, 8: img.shape[2]+ 8]=img

seg_img=np.zeros((240,240,155))
for x in range(0, img_pad.shape[0]- 16, 9):
    for y in range(0, img_pad.shape[1]- 16, 9):
        for z in range(0, img_pad.shape[2]- 16, 9):
            #25 cube high res
            send_data= img_pad[x:min(x+ 25, img_pad.shape[0]),y:min(y+ 25, img_pad.shape[1]), 
                               z:min(z+ 25, img_pad.shape[2])]
            pad_high_res=np.zeros((25,25,25))
            if(send_data.shape == (25,25,25)):
                pad_high_res= send_data
            else:
                x_offset=int((25 - send_data.shape[0])/2)
                y_offset=int((25 - send_data.shape[1])/2)
                z_offset=int((25 - send_data.shape[2])/2)
                pad_high_res[x_offset: x_offset+ send_data.shape[0], y_offset: y_offset+ send_data.shape[1],
                         z_offset: z_offset+ send_data.shape[2]]= send_data
            #51 cube low res
            send_data= img_pad[x-13:min(x+ 38, img_pad.shape[0]),y-13:min(y+ 38, img_pad.shape[1]), 
                               z-13:min(z+ 38, img_pad.shape[2])]
            pad_low_res= np.zeros((51,51,51))
            if(send_data.shape ==(51,51,51)):
                pad_low_res= send_data
            else:
                x_offset=int((51 - send_data.shape[0])/2)
                y_offset=int((51 - send_data.shape[1])/2)
                z_offset=int((51 - send_data.shape[2])/2)
                pad_low_res[x_offset: x_offset+ send_data.shape[0], y_offset: y_offset+ send_data.shape[1],
                         z_offset: z_offset+ send_data.shape[2]]= send_data
            return_data=demo(pad_high_res, pad_low_res)
    
            seg_img[x if x<=231 else 231:x+9, y if y<=231 else 231: y+9, z if z<=146 else 146:z+9]=return_data
print(np.min(seg_img))

# %%
# model = model.to(device)
# path = '/home/uavws/pranjal/MICCAI_BraTS_2018_Data_Training/HGG_patches/Brats18_CBICA_ANZ_1/'

# patches  = next(os.walk(path))[1]
# wts, tcs, ets = [], [], []
# count = 0
# for patch in tqdm(patches):
#     if patch.__contains__('NON'):
#         continue
# #     print (patch)
#     mask  =  nib.load(path+'/'+patch+'/'+'seg_9cube.nii.gz').get_data()
#     seg   =  nib.load(path+'/'+patch+'/'+'seg_9cube.nii.gz').get_data()
#     flair =  nib.load(path+'/'+patch+'/'+'flair_high_res_25cube.nii.gz').get_data()
#     t1    =  nib.load(path+'/'+patch+'/'+'t1_high_res_25cube.nii.gz').get_data()
#     t1ce  =  nib.load(path+'/'+patch+'/'+'t1ce_high_res_25cube.nii.gz').get_data()
#     t2    =  nib.load(path+'/'+patch+'/'+'t2_high_res_25cube.nii.gz').get_data()
#     affine=  nib.load(path+'/'+patch+'/'+'seg_9cube.nii.gz').affine
#     seg[seg == 4] = 3
#     high = np.zeros((1, 4, 25, 25, 25))
#     low  = np.zeros((1, 4, 19, 19, 19))


#     high[0, 0, :, :, :] = flair
#     high[0, 1, :, :, :] = t2
#     high[0, 2, :, :, :] = t1
#     high[0, 3, :, :, :] = t1ce

#     flair =  nib.load(path+'/'+patch+'/'+'flair_low_res_19cube.nii.gz').get_data()
#     t1    =  nib.load(path+'/'+patch+'/'+'t1_low_res_19cube.nii.gz').get_data()
#     t1ce  =  nib.load(path+'/'+patch+'/'+'t1ce_low_res_19cube.nii.gz').get_data()
#     t2    =  nib.load(path+'/'+patch+'/'+'t2_low_res_19cube.nii.gz').get_data()

#     low[0, 0, :, :, :] = flair
#     low[0, 1, :, :, :] = t2
#     low[0, 2, :, :, :] = t1
#     low[0, 3, :, :, :] = t1ce

#     high = Variable(torch.from_numpy(high)).to(device).float()
#     low  = Variable(torch.from_numpy(low)).to(device).float()
#     pred = torch.exp(model(high, low).detach()).cpu().numpy()

#     pred = np.argmax(pred, axis=1)[0]

#     # mask = get_localization(t1, t1ce, t2, flair)
#     # mask = perform_postprocessing(mask)
#     # final_pred     = inner_class_classification(t1, t1ce, t2, flair, mask, model)
#     wt, tc, et     = get_dice_score(pred, seg)
# #     print ('wt_dice_score = '+str(wt)+'; tc_dice_score='+str(tc)+'; et_dice_score='+str(et))
#     wts.append(wt)
#     tcs.append(tc)
#     ets.append(et)
#     count += 1
# #     vol = nib.Nifti1Image(pred, affine)
# #     vol.set_data_dtype(np.uint8)
# #     nib.save(vol, './test.nii.gz')
def demo(img1 ,img2):
     return(np.random.randint(1,4,size=(9,9,9)))    
def testing(model,high,low):
    
#     indices=np.argwhere(mask_volume>0)
    
#     x1=np.min(indices[:,0])
#     x2=np.max(indices[:,0])
#     y1=np.min(indices[:,1])
#     y2=np.max(indices[:,1])
#     z1=np.min(indices[:,2])
#     z2=np.max(indices[:,2])
    
#     tumor_region=np.zeros((1, 4, x2-x1+1+16, y2-y1+1+16, z2-z1+1+16))
#     #tumor_low_res=np.zeros(1, 4, x2-x1, y2-y1, z2-z1)
    
    tumor_high_res=high.data.cpu().numpy()
    tumor_low_res=low.data.cpu().numpy()
    seg_img=np.zeros((25,25,25))
    for x in range(0, 25, 9):
        for y in range(0, 25, 9):
            for z in range(0, 25, 9):
                #25 cube high res
                send_data= tumor_high_res[:, :, x:min(x+ 25, tumor_high_res.shape[2]),y:min(y+ 25, tumor_high_res.shape[3]), 
                                   z:min(z+ 25, tumor_high_res.shape[4])]
                pad_high_res=np.zeros((1,4,25,25,25))
                if(send_data.shape == (1,4,25,25,25)):
                    pad_high_res= send_data
                else:
                    print(send_data.shape)
                    x_offset=int((25 - send_data.shape[2])/2)
                    y_offset=int((25 - send_data.shape[3])/2)
                    z_offset=int((25 - send_data.shape[4])/2)
                   
                    pad_high_res[:, :, x_offset: x_offset+ send_data.shape[2], y_offset: y_offset+ send_data.shape[3],
                             z_offset: z_offset+ send_data.shape[4]]= send_data
                #19 cube low res
                send_data= tumor_low_res[:, :, x:min(x+ 19, tumor_low_res.shape[2]),y:min(y+ 19, tumor_low_res.shape[3]), 
                                   z:min(z+ 19, tumor_low_res.shape[4])]
                pad_low_res= np.zeros((1,4,19,19,19))
                if(send_data.shape ==(1,4,19,19,19)):
                    pad_low_res= send_data
                else:
                    x_offset=int((19 - send_data.shape[2])/2)
                    y_offset=int((19 - send_data.shape[3])/2)
                    z_offset=int((19 - send_data.shape[4])/2)
                    pad_low_res[:,:,x_offset: x_offset+ send_data.shape[2], y_offset: y_offset+ send_data.shape[3],
                             z_offset: z_offset+ send_data.shape[4]]= send_data
                high_tensor = Variable(torch.from_numpy(pad_high_res)).to(device).float()
                low_tensor  = Variable(torch.from_numpy(pad_low_res)).to(device).float()
                print(high_tensor.size)
                print(low_tensor.size)
                pred=np.zeros(())
                pred = torch.exp(model(high_tensor, low_tensor).detach()).cpu().numpy()
                #pred = np.argmax(pred, axis=1)[0]

                return_data = np.argmax(pred, axis=1)[0]

                # mask = get_localization(t1, t1ce, t2, flair)
                # mask = perform_postprocessing(mask)
                # final_pred     = inner_class_classification(t1, t1ce, t2, flair, mask, model)
                #return_data=demo(pad_high_res, pad_low_res)
#                 print(np.sum(return_data))
#                 print('hey')
                seg_img[x if x<=seg_img.shape[0]-9 else seg_img.shape[0]-9:x+9, y if y<=seg_img.shape[1]-9
                        else seg_img.shape[1]-9: y+9, z if z<=seg_img.shape[2]-9 else seg_img.shape[2]-9:z+9]=return_data
    return(seg_img)

# %%
def get_whole_tumor(data):
    return data>0

def get_tumor_core(data):
    return np.logical_or(data==1,data==3)

def get_enhancing_tumor(data):
    return data==3

def get_dice_score(prediction, ground_truth):
    masks=(get_whole_tumor, get_tumor_core, get_enhancing_tumor)
    p    =np.uint8(prediction)
    gt   =np.uint8(ground_truth)
    # print(np.unique(p),np.unique(gt))
    wt,tc,et=[2*np.sum(func(p)*func(gt)) / (np.sum(func(p)) + np.sum(func(gt))) for func in masks]
    return wt, tc, et

# %%
model = model.to(device)
path = '/home/uavws/pranjal/MICCAI_BraTS_2018_Data_Training/HGG_patches/Brats18_CBICA_ANZ_1/'

patches  = next(os.walk(path))[1]
wts, tcs, ets = [], [], []
count = 0
for patch in tqdm(patches):
    if patch.__contains__('NON'):
         continue
 #   print (patch)
    #indices=np.argwhere(mask>0)
    
#     x1=np.min(indices[:,0])
#     x2=np.max(indices[:,0])
#     y1=np.min(indices[:,1])
#     y2=np.max(indices[:,1])
#     z1=np.min(indices[:,2])
#     z2=np.max(indices[:,2])
    mask  =  nib.load(path+'/'+patch+'/'+'seg_9cube.nii.gz').get_data()
    seg   =  nib.load(path+'/'+patch+'/'+'seg_9cube.nii.gz').get_data()
    flair =  nib.load(path+'/'+patch+'/'+'flair_high_res_25cube.nii.gz').get_data()
    t1    =  nib.load(path+'/'+patch+'/'+'t1_high_res_25cube.nii.gz').get_data()
    t1ce  =  nib.load(path+'/'+patch+'/'+'t1ce_high_res_25cube.nii.gz').get_data()
    t2    =  nib.load(path+'/'+patch+'/'+'t2_high_res_25cube.nii.gz').get_data()
    affine=  nib.load(path+'/'+patch+'/'+'seg_9cube.nii.gz').affine
    seg[seg == 4] = 3
    high = np.zeros((1, 4, 25, 25, 25))+np.min(seg)
    low  = np.zeros((1, 4, 19, 19, 19))+np.min(seg)


    high[0, 0, :, :, :] = flair
    high[0, 1, :, :, :] = t2
    high[0, 2, :, :, :] = t1
    high[0, 3, :, :, :] = t1ce

    flair =  nib.load(path+'/'+patch+'/'+'flair_low_res_19cube.nii.gz').get_data()
    t1    =  nib.load(path+'/'+patch+'/'+'t1_low_res_19cube.nii.gz').get_data()
    t1ce  =  nib.load(path+'/'+patch+'/'+'t1ce_low_res_19cube.nii.gz').get_data()
    t2    =  nib.load(path+'/'+patch+'/'+'t2_low_res_19cube.nii.gz').get_data()

    low[0, 0, :, :, :] = flair
    low[0, 1, :, :, :] = t2
    low[0, 2, :, :, :] = t1
    low[0, 3, :, :, :] = t1ce

    high = Variable(torch.from_numpy(high)).to(device).float()
    low  = Variable(torch.from_numpy(low)).to(device).float()
    #pred = torch.exp(model(high, low).detach()).cpu().numpy()
    pred = torch.exp(model(high,low).detach()).cpu().numpy()
    pred = np.argmax(pred, axis=1)[0]
    wt, tc, et     = get_dice_score(pred, seg)
    print ('wt_dice_score = '+str(wt)+'; tc_dice_score='+str(tc)+'; et_dice_score='+str(et))
    wts.append(wt)
    tcs.append(tc)
    ets.append(et)
# Out:
# ...
# wt_dice_score = 0.9152215799614644; tc_dice_score=0.9483960948396095; et_dice_score=0.6153846153846154
# /home/uavws/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in long_scalars
#   from ipykernel import kernelapp as app
# wt_dice_score = 0.0; tc_dice_score=nan; et_dice_score=nan
# /home/uavws/anaconda3/lib/python3.6/site-packages/tqdm/_monitor.py:89: TqdmSynchronisationWarning: Set changed size during iteration (see https://github.com/tqdm/tqdm/issues/481)
#   TqdmSynchronisationWarning)
# wt_dice_score = 0.9993136582017845; tc_dice_score=0.9993136582017845; et_dice_score=0.8913043478260869
# wt_dice_score = 0.0; tc_dice_score=nan; et_dice_score=nan
# wt_dice_score = 0.9126760563380282; tc_dice_score=0.7168949771689498; et_dice_score=0.6424870466321243
# wt_dice_score = 1.0; tc_dice_score=0.656641604010025; et_dice_score=0.697986577181208
# wt_dice_score = 0.5569620253164557; tc_dice_score=nan; et_dice_score=nan
# ...

# %%
sum(wts)/len(wts),   sum(tcs)/len(tcs),   sum(ets)/len(ets)
# Out:
# (0.5874573466139974, nan, nan)
# /home/uavws/anaconda3/lib/python3.6/site-packages/tqdm/_monitor.py:89: TqdmSynchronisationWarning: Set changed size during iteration (see https://github.com/tqdm/tqdm/issues/481)
#   TqdmSynchronisationWarning)

# %%
tcs=[x for x in tcs if str(x) !='nan']
ets=[x for x in ets if str(x) !='nan']
sum(wts)/len(wts),   sum(tcs)/len(tcs),   sum(ets)/len(ets)
# Out:
# (0.5874573466139974, 0.6567875478093212, 0.5951287084960213)
# /home/uavws/anaconda3/lib/python3.6/site-packages/tqdm/_monitor.py:89: TqdmSynchronisationWarning: Set changed size during iteration (see https://github.com/tqdm/tqdm/issues/481)
#   TqdmSynchronisationWarning)

# %%
def demo(img1 ,img2):
     return(np.random.randint(1,4,size=(9,9,9)))    
def testing(mask_volume, flair, t1, t1ce, t2):
    
    indices=np.argwhere(mask_volume>0)
    
    x1=np.min(indices[:,0])
    x2=np.max(indices[:,0])
    y1=np.min(indices[:,1])
    y2=np.max(indices[:,1])
    z1=np.min(indices[:,2])
    z2=np.max(indices[:,2])
    
    tumor_region=np.zeros((1, 4, x2-x1+1+16, y2-y1+1+16, z2-z1+1+16))
    #tumor_low_res=np.zeros(1, 4, x2-x1, y2-y1, z2-z1)
    
#     high = np.zeros((1, 4, 25, 25, 25))
#     low  = np.zeros((1, 4, 19, 19, 19))
    tumor_region[0, 0, 8:8+x2-x1, 8:8+y2-y1, 8:z2-z1] = flair[x2-x1, y2-y1, z2-z1]
    tumor_region[0, 1, 8:8+x2-x1, 8:8+y2-y1, 8:z2-z1] = t2[x2-x1, y2-y1, z2-z1]
    tumor_region[0, 2, 8:8+x2-x1, 8:8+y2-y1, 8:z2-z1] = t1[x2-x1, y2-y1, z2-z1]
    tumor_region[0, 3, 8:8+x2-x1, 8:8+y2-y1, 8:z2-z1] = t1ce[x2-x1, y2-y1, z2-z1]

#     tumor_low_res[0, 0, :, :, :] = flair[x2-x1, y2-y1, z2-z1]
#     tumor_low_res[0, 1, :, :, :] = t2[x2-x1, y2-y1, z2-z1]
#     tumor_low_res[0, 2, :, :, :] = t1[x2-x1, y2-y1, z2-z1]
#     tumor_low_res[0, 3, :, :, :] = t1ce[x2-x1, y2-y1, z2-z1]
    
    
    seg_img=np.zeros((x2-x1+1, y2-y1+1, z2-z1+1))
    
    for x in range(0, tumor_region.shape[2]-16, 9):
        for y in range(0, tumor_region.shape[3]-16, 9):
            for z in range(0, tumor_region.shape[4]-16, 9):
                #25 cube high res
                send_data= tumor_region[:, :, x:min(x+ 25, tumor_region.shape[2]),y:min(y+ 25, tumor_region.shape[3]), 
                                   z:min(z+ 25, tumor_region.shape[4])]
                pad_high_res=np.zeros((1,4,25,25,25))
                if(send_data.shape == (1,4,25,25,25)):
                    pad_high_res= send_data
                else:
                    print(send_data.shape)
                    x_offset=int((25 - send_data.shape[2])/2)
                    y_offset=int((25 - send_data.shape[3])/2)
                    z_offset=int((25 - send_data.shape[4])/2)
                   
                    pad_high_res[:, :, x_offset: x_offset+ send_data.shape[2], y_offset: y_offset+ send_data.shape[3],
                             z_offset: z_offset+ send_data.shape[4]]= send_data
                #51 cube low res
                send_data= tumor_region[:, :, x-13:min(x+ 38, tumor_region.shape[2]),y-13:min(y+ 38, tumor_region.shape[3]), 
                                   z-13:min(z+ 38, tumor_region.shape[4])]
                pad_low_res= np.zeros((1,4,51,51,51))
                if(send_data.shape ==(1,4,51,51,51)):
                    pad_low_res= send_data
                else:
                    x_offset=int((51 - send_data.shape[2])/2)
                    y_offset=int((51 - send_data.shape[3])/2)
                    z_offset=int((51 - send_data.shape[4])/2)
                    pad_low_res[:,:,x_offset: x_offset+ send_data.shape[2], y_offset: y_offset+ send_data.shape[3],
                             z_offset: z_offset+ send_data.shape[4]]= send_data
#                 high = Variable(torch.from_numpy(pad_high_res)).to(device).float()
#                 low  = Variable(torch.from_numpy(pad_low_res)).to(device).float()
#                 pred = torch.exp(model(high, low).detach()).cpu().numpy()

#                 return_dat = np.argmax(pred, axis=1)[0]

                # mask = get_localization(t1, t1ce, t2, flair)
                # mask = perform_postprocessing(mask)
                # final_pred     = inner_class_classification(t1, t1ce, t2, flair, mask, model)
                return_data=demo(pad_high_res, pad_low_res)
#                 print(np.sum(return_data))
#                 print('hey')
                seg_img[x if x<=seg_img.shape[0]-9 else seg_img.shape[0]-9:x+9, y if y<=seg_img.shape[1]-9
                        else seg_img.shape[1]-9: y+9, z if z<=seg_img.shape[2]-9 else seg_img.shape[2]-9:z+9]=return_data
    return(seg_img)
